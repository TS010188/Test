# %% [markdown]
# <a href="https://colab.research.google.com/github/TS010188/Test/blob/master/GDP_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

pd.options.display.max_rows = 10

# read data to a data frame

df = pd.read_csv("./sample_data/GDP.csv")

# %%
df.head(5)
# Out:
#                  Country    1999    2000    2001    2002    2003    2004  \
# 0  Afghanistan, Rep. of.       0       0       0   4.084   4.585   5.971
# 1                Albania   3.444   3.695   4.096   4.456     5.6   7.452
# 2                Algeria  48.845  54.749  55.181  57.053  68.013  85.016
# 3                 Angola   6.153   9.135   8.936  11.386  13.956    19.8
# 4    Antigua and Barbuda   0.652   0.678    0.71   0.718   0.754   0.818
#
#      2005     2006     2007  ...     2013     2014     2015    2016     2017  \
# 0   7.309    8.399    9.892  ...   21.555   24.304        0       0        0
# 1   8.376    9.133   10.163  ...    14.91   16.053   11.591  12.204   13.214
# 2  102.38  114.322  116.158  ...  190.432  203.449  175.077  181.71  192.256
# 3  30.632   43.759    55.37  ...  136.415  151.089  102.011  98.815  105.369
# 4   0.875    0.962    1.026  ...    1.404    1.494    1.285   1.328    1.386
#
#       2018     2019    2020     2021     2022
# ...

# %%
df.tail(5)
# Out:
#                 Country    1999     2000     2001    2002    2003    2004  \
# 175           Venezuela  97.977  117.153  122.872  92.889  83.442   112.8
# 176             Vietnam  28.684   31.196   32.504  35.148   39.63  45.548
# 177  Yemen, Republic of    7.53    9.561    9.533   9.985  11.869  13.565
# 178              Zambia   3.132    3.238     3.64   3.775   4.326    5.44
# 179            Zimbabwe   5.963    8.136   12.883  30.856  10.515     4.7
#
#         2005     2006     2007  ...     2013     2014     2015     2016  \
# 175  143.443  181.608  219.372  ...  403.123  409.562  131.855  133.534
# 176   53.053   60.995   68.298  ...  135.729  148.914  198.805   214.75
# 177   15.193     18.7   21.657  ...   40.003   42.687        0        0
# 178    7.271   10.942   10.104  ...   21.829   23.613   24.466   25.158
# 179    4.552     5.54   18.281  ...    6.214    6.851   13.905   14.292
#
#         2017     2018     2019     2020     2021     2022
# ...

# %%
df.sample(5)
# Out:
#                        Country     1999     2000    2001     2002     2003  \
# 167                     Uganda    6.008     5.91    5.65    5.835    6.243
# 168                    Ukraine   31.569   31.262  38.009   42.393   50.133
# 32                        Chad    1.537    1.389   1.711    1.995    2.728
# 22                      Brazil  586.922  644.283  554.41  505.712  552.239
# 160  Timor-Leste, Dem. Rep. of     0.27    0.316   0.368    0.343    0.336
#
#         2004     2005      2006      2007  ...      2013      2014      2015  \
# 167    6.817    8.734     9.443    10.492  ...    21.451    22.991    24.943
# 168   64.883   86.044   106.072   122.802  ...   160.619   175.949    90.138
# 32     4.421    5.896     6.547     6.139  ...     9.046     9.205    11.688
# 22   663.552  882.043  1,067.71  1,177.71  ...  2,036.24  2,155.68  1,799.61
# 160    0.339     0.35     0.356     0.493  ...     1.136     1.337         0
#
# ...

# %%
df[df["Country"] == "India"]
# Out:
#    Country    1999     2000     2001     2002     2003     2004     2005  \
# 74   India  440.76  461.329  473.867  494.848  576.547  667.342  780.784
#
#        2006    2007  ...      2013      2014      2015      2016      2017  \
# 74  886.867  984.21  ...  1,740.41  1,908.33  2,182.58  2,384.73  2,607.41
#
#         2018      2019      2020      2021      2022
# 74  2,846.16  3,131.95  3,443.60  2,946.06  3,250.08
#
# [1 rows x 24 columns]

# %%
df[(df["Country"] == "China") | (df["Country"] == "India")]
# Out:
#    Country      1999      2000      2001      2002      2003      2004  \
# 34   China  1,083.28  1,198.48  1,324.81  1,453.84  1,640.97  1,931.64
# 74   India    440.76   461.329   473.867   494.848   576.547   667.342
#
#         2005      2006      2007  ...      2013      2014       2015  \
# 34  2,243.69  2,630.11  3,051.24  ...  7,287.76  8,283.35  11,384.76
# 74   780.784   886.867    984.21  ...  1,740.41  1,908.33   2,182.58
#
#          2016       2017       2018       2019       2020       2021  \
# 34  12,253.98  13,173.59  14,272.35  15,620.71  17,100.06  16,862.98
# 74   2,384.73   2,607.41   2,846.16   3,131.95   3,443.60   2,946.06
#
#          2022
# 34  18,463.13
# 74   3,250.08
#
# [2 rows x 24 columns]

# %%
df.iloc[15:25]
# Out:
#                    Country     1999     2000     2001     2002     2003  \
# 15                 Belgium  253.889  232.934  231.928   252.66  310.514
# 16                  Belize    0.732    0.832    0.871    0.932    0.988
# 17                   Benin    2.492    2.383    2.502    2.817    3.565
# 18                  Bhutan     0.43     0.46    0.493    0.545    0.611
# 19                 Bolivia    8.298    8.412    8.154    7.917    8.102
# 20  Bosnia and Herzegovina    4.995    5.298    5.558    6.184    7.801
# 21                Botswana    5.629    6.193     6.06    5.959    8.318
# 22                  Brazil  586.922  644.283   554.41  505.712  552.239
# 23       Brunei Darussalam      4.6    6.001    5.601    5.843    6.557
# 24                Bulgaria   12.977   12.639   13.605   15.614   19.974
#
#        2004     2005      2006      2007  ...      2013      2014      2015  \
# 15  359.155  372.726    393.59   423.541  ...   520.026   535.079   458.651
# ...

# %%
df.query('Country == "China"')
# Out:
#    Country      1999      2000      2001      2002      2003      2004  \
# 34   China  1,083.28  1,198.48  1,324.81  1,453.84  1,640.97  1,931.64
#
#         2005      2006      2007  ...      2013      2014       2015  \
# 34  2,243.69  2,630.11  3,051.24  ...  7,287.76  8,283.35  11,384.76
#
#          2016       2017       2018       2019       2020       2021  \
# 34  12,253.98  13,173.59  14,272.35  15,620.71  17,100.06  16,862.98
#
#          2022
# 34  18,463.13
#
# [1 rows x 24 columns]

# %%
list_of_countries = ["United States", "China", "India"]

# %%
top3 = df.query('Country in @list_of_countries')
top3.head(5)
# Out:
#            Country      1999      2000       2001       2002       2003  \
# 34           China  1,083.28  1,198.48   1,324.81   1,453.84   1,640.97
# 74           India    440.76   461.329    473.867    494.848    576.547
# 171  United States  9,268.43  9,816.98  10,127.95  10,469.60  10,960.75
#
#           2004       2005       2006       2007  ...       2013       2014  \
# 34    1,931.64   2,243.69   2,630.11   3,051.24  ...   7,287.76   8,283.35
# 74     667.342    780.784    886.867     984.21  ...   1,740.41   1,908.33
# 171  11,712.48  12,455.83  13,244.55  13,770.31  ...  16,729.38  17,419.35
#
#           2015       2016       2017       2018       2019       2020  \
# 34   11,384.76  12,253.98  13,173.59  14,272.35  15,620.71  17,100.06
# 74    2,182.58   2,384.73   2,607.41   2,846.16   3,131.95   3,443.60
# 171  17,968.20  18,697.92  19,555.87  20,493.25  21,404.19  22,294.11
#
#           2021       2022
# 34   16,862.98  18,463.13
# 74    2,946.06   3,250.08
# ...
